# %% [markdown]
# Connected to Python 3.13.15

# %%
import pandas as pd

query = """
SELECT p.id, p.sku, p.name, p.description, p.price, p.category_id, p.image_url, p.stock, p.created_at, c.name AS category_name 
FROM products p 
LEFT JOIN categories c ON p.category_id=c.id 
ORDER BY p.created_at DESC
"""

products = pd.read_sql(query, connection)
print(products)
# Out:
#   Cell In[5], line 1
#     SELECT p.id,p.sku,p.name,p.description,p.price,p.category_id,p.image_url,p.stock,p.created_at,c.name AS category_name FROM products p LEFT JOIN categories c ON p.category_id=c.id ORDER BY p.created_at DESC
#            ^
# SyntaxError: invalid syntax
